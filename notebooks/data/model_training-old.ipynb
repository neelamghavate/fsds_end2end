# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\ineuron\fsds_end2end\notebooks\data\model_training.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/ineuron/fsds_end2end/notebooks/data/model_training.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# File d:\ineuron\fsds_end2end\env\lib\site-packages\pandas\__init__.py:73
#      70 # let init-time option registration happen
#      71 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 73 from pandas.core.api import (
#      74     # dtype
#      75     ArrowDtype,
#      76     Int8Dtype,
#      77     Int16Dtype,
#      78     Int32Dtype,
#      79     Int64Dtype,
#      80     UInt8Dtype,
#      81     UInt16Dtype,
#      82     UInt32Dtype,
#      83     UInt64Dtype,
#      84     Float32Dtype,
#      85     Float64Dtype,
#      86     CategoricalDtype,
# ...

# %%
data = pd.read_csv(r"D:\ineuron\fsds_end2end\notebooks\data\gemstone.csv")
data = data.drop(labels="id",axis=1)
data.shape
# Out:
# (193573, 10)

# %%
data
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]

# %%
X = data.iloc[:,:-1]
X
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48
#
# [193573 rows x 9 columns]

# %%
y = data.iloc[:,-1:]
y
# Out:
#         price
# 0       13619
# 1       13387
# 2        2772
# 3         666
# 4       14453
# ...       ...
# 193568   1130
# 193569   2874
# 193570   3036
# 193571    681
# 193572   2258
#
# [193573 rows x 1 columns]

# %%
X.shape
# Out:
# (193573, 9)

# %%
X.dtypes
X_categorical = data.columns[data.dtype=="object"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\ineuron\fsds_end2end\notebooks\data\model_training.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/ineuron/fsds_end2end/notebooks/data/model_training.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> X.dtypes
#       <a href='vscode-notebook-cell:/d%3A/ineuron/fsds_end2end/notebooks/data/model_training.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> X_categorical = data.columns[data.dtype=="object"]
#
# NameError: name 'X' is not defined
